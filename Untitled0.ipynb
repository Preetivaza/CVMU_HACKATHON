# %% [markdown]
# <a href="https://colab.research.google.com/github/Preetivaza/CVMU_HACKATHON/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install ultralytics

# %%
# !rm pothole.v17i.yolov8.zip
# Out:
# rm: cannot remove 'pothole.v17i.yolov8.zip': No such file or directory

# %%
# !pip install roboflow

# %%
# !ls
# Out:
# drive  pothole-17  runs  sample_data  yolov8n.pt

# %%
# !ls pothole-17
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
# !pip install ultralytics

# %%
# !pip install roboflow

from roboflow import Roboflow
rf = Roboflow(api_key="2b9LJbJpTdggJ4yz88An")
project = rf.workspace("yeeun-kim-fyvoj").project("pothole-vhmow")
version = project.version(17)
dataset = version.download("yolov8")
# Out:
# ...
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pothole-17 in yolov8:: 100%|██████████| 5448/5448 [00:00<00:00, 7050.74it/s]

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="pothole-17/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    device=0
)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/pothole_project
# Out:
# /content/drive/MyDrive/pothole_project

# %%
# !pwd
# Out:
# /content/drive/MyDrive/pothole_project

# %%
# !unzip -o pothole.v17i.yolov8.zip
# Out:
# Archive:  pothole.v17i.yolov8.zip
#   End-of-central-directory signature not found.  Either this file is not
#   a zipfile, or it constitutes one disk of a multi-part archive.  In the
#   latter case the central directory and zipfile comment will be found on
#   the last disk(s) of this archive.
# unzip:  cannot find zipfile directory in one of pothole.v17i.yolov8.zip or
#         pothole.v17i.yolov8.zip.zip, and cannot find pothole.v17i.yolov8.zip.ZIP, period.

# %%
# !rm pothole.v17i.yolov8.zip
# Out:
# rm: cannot remove 'pothole.v17i.yolov8.zip': No such file or directory

# %%
# %cd /content/drive/MyDrive/pothole_project
# Out:
# /content/drive/MyDrive/pothole_project

# %%
# !pwd
# Out:
# /content/drive/MyDrive/pothole_project

# %%
# !pip install roboflow

# %%
from roboflow import Roboflow
rf = Roboflow(api_key="2b9LJbJpTdggJ4yz88An")
project = rf.workspace("yeeun-kim-fyvoj").project("pothole-vhmow")
version = project.version(17)
dataset = version.download("yolov8")
# Out:
# loading Roboflow workspace...
# loading Roboflow project...
# ...
# Extracting Dataset Version Zip to pothole-17 in yolov8:: 100%|██████████| 5448/5448 [00:50<00:00, 107.71it/s]

# %%
# !ls
# Out:
# pothole-17

# %%
# !ls pothole-17
# Out:
# data.yaml  README.dataset.txt  README.roboflow.txt  test  train  valid

# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="pothole-17/data.yaml",
    epochs=30,
    imgsz=640,
    batch=16,
    device=0,
    project="/content/drive/MyDrive/pothole_project",
    name="training_v1"
)
# Out:
# Ultralytics 8.4.19 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
import torch
print(torch.cuda.is_available())
# Out:
# True

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO
print("YOLOv8 installed successfully")
# Out:
# YOLOv8 installed successfully

# %%
from ultralytics import YOLO
model = YOLO("yolov8n.pt")

results = model("https://ultralytics.com/images/bus.jpg", show=True)
# Out:
# WARNING ⚠️ Environment does not support cv2.imshow() or PIL Image.show()
#
#
# ...
# image 1/1 /content/drive/MyDrive/pothole_project/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 49.1ms
# Speed: 2.8ms preprocess, 49.1ms inference, 1.7ms postprocess per image at shape (1, 3, 640, 480)

# %%
from ultralytics import YOLO

model = YOLO("/content/drive/MyDrive/pothole_project/training_v12/weights/best.pt")

results = model("https://ultralytics.com/images/bus.jpg")

print(results)
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/drive/MyDrive/pothole_project/bus.jpg: 640x480 (no detections), 18.5ms
# Speed: 4.9ms preprocess, 18.5ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 480)
# [ultralytics.engine.results.Results object with attributes:
#
# boxes: ultralytics.engine.results.Boxes object
# keypoints: None
# masks: None
# names: {0: 'pothole'}
# obb: None
# orig_img: array([[[119, 146, 172],
#         [121, 148, 174],
#         [122, 152, 177],
#         ...,
#         [161, 171, 188],
#         [160, 170, 187],
#         [160, 170, 187]],
#
#        [[120, 147, 173],
#         [122, 149, 175],
#         [123, 153, 178],
#         ...,
#         [161, 171, 188],
#         [160, 170, 187],
#         [160, 170, 187]],
#
#        [[123, 150, 176],
#         [124, 151, 177],
#         [125, 155, 180],
#         ...,
#         [161, 171, 188],
#         [160, 170, 187],
#         [160, 170, 187]],
#
# ...

# %%
from ultralytics import YOLO

# Load pretrained model just to test pipeline
model = YOLO("yolov8n.pt")

# Use sample image from internet
results = model("https://ultralytics.com/images/bus.jpg", save=True)

print("Pipeline Working ✅")
# Out:
# Found https://ultralytics.com/images/bus.jpg locally at bus.jpg
# image 1/1 /content/drive/MyDrive/pothole_project/bus.jpg: 640x480 4 persons, 1 bus, 1 stop sign, 7.8ms
# Speed: 2.4ms preprocess, 7.8ms inference, 1.3ms postprocess per image at shape (1, 3, 640, 480)
# Results saved to /content/drive/MyDrive/pothole_project/runs/detect/predict
# Pipeline Working ✅

# %%
import cv2
import numpy as np

# Create dummy frames (simulate video)
dummy_frames = []

for i in range(10):
    frame = np.random.randint(0, 255, (640, 640, 3), dtype=np.uint8)
    dummy_frames.append(frame)

print("Dummy video frames generated:", len(dummy_frames))
# Out:
# Dummy video frames generated: 10

# %%
model = YOLO("yolov8n.pt")

for i, frame in enumerate(dummy_frames):
    results = model(frame)
    print(f"Frame {i} processed")
# Out:
# 0: 640x640 (no detections), 12.1ms
# Speed: 1.9ms preprocess, 12.1ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 0 processed
#
# 0: 640x640 (no detections), 11.8ms
# Speed: 2.7ms preprocess, 11.8ms inference, 0.9ms postprocess per image at shape (1, 3, 640, 640)
# Frame 1 processed
#
# 0: 640x640 (no detections), 10.4ms
# Speed: 2.4ms preprocess, 10.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 2 processed
#
# 0: 640x640 (no detections), 8.7ms
# Speed: 1.9ms preprocess, 8.7ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 3 processed
#
# 0: 640x640 (no detections), 8.4ms
# Speed: 2.1ms preprocess, 8.4ms inference, 0.7ms postprocess per image at shape (1, 3, 640, 640)
# Frame 4 processed
#
# 0: 640x640 (no detections), 11.4ms
# Speed: 1.9ms preprocess, 11.4ms inference, 0.8ms postprocess per image at shape (1, 3, 640, 640)
# Frame 5 processed
#
# 0: 640x640 (no detections), 9.1ms
# ...
